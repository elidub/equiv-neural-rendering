# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
# %matplotlib inline
import imageio
import torch
import torchvision
from skimage.transform import resize
import json
from transforms3d.conversions import rad2deg
from torchvision.transforms import ToTensor
from models.neural_renderer import load_model
import pickle


from test_blender import plot_per_4_imgs
# Out:
# Using device: cpu

# %%
sets = [
    'chairs/data_all/rot_dataset/1a6f615e8b1b5ae4dbbc9440457e303e', 
    'chairs/data_org/chairs-train/1a6f615e8b1b5ae4dbbc9440457e303e',
]

for t in sets:
    print(t)
    with open(f'figs/{t}.pkl', 'rb') as f:
        imgs_all = pickle.load(f)
    plot_per_4_imgs(imgs_all)
# Out:
# chairs/data_all/rot_dataset/1a6f615e8b1b5ae4dbbc9440457e303e
# chairs/data_org/chairs-train/1a6f615e8b1b5ae4dbbc9440457e303e
